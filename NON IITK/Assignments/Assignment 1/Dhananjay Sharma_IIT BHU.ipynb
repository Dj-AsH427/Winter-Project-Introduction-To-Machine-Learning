# %% [markdown]
# Q1. Using NumPy, create a 3D array of shape (4, 4, 4) filled with random numbers between 1 and 100. Find the z score normalisation of each element of the array.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a1=np.random.randint(1,100,(4,4,4))
mean=a1.mean()
std=a1.std()
norm=(a1-mean)/std

print("Array is:",a1,"\n The Z-score normalisation of every element is:",norm)
# Out:
# Array is: [[[71 32 71 34]
#   [99 47 56 98]
#   [31 55 40 86]
#   [11 66 84 63]]
#
#  [[35 12 21 73]
#   [26 12 85 62]
#   [40 98 43 11]
#   [46 86 55 76]]
#
#  [[84 77 44 62]
#   [47 56 94 10]
#   [49 75 46 83]
#   [99 32  6 57]]
#
#  [[46 39 64 27]
#   [ 3 80 82 47]
#   [73 21 65 59]
#   [50 74 95 39]]]
#  The Z-score normalisation of every element is: [[[ 0.61971745 -0.87623492  0.61971745 -0.79951941]
#   [ 1.69373453 -0.30086863  0.04435115  1.65537678]
#   [-0.91459267  0.0059934  -0.5693729   1.19508374]
#   [-1.68174773  0.42792868  1.11836824  0.31285542]]
#
#  [[-0.76116166 -1.64338998 -1.2981702   0.69643295]
#   [-1.10638144 -1.64338998  1.15672599  0.27449767]
#   [-0.5693729   1.65537678 -0.45429964 -1.68174773]
#   [-0.33922638  1.19508374  0.0059934   0.81150621]]
#
#  [[ 1.11836824  0.84986397 -0.41594188  0.27449767]
#   [-0.30086863  0.04435115  1.50194577 -1.72010549]
#   [-0.22415312  0.77314846 -0.33922638  1.08001048]
#   [ 1.69373453 -0.87623492 -1.8735365   0.0827089 ]]
#
#  [[-0.33922638 -0.60773065  0.35121318 -1.06802369]
#   [-1.98860976  0.96493722  1.04165273 -0.30086863]
#   [ 0.69643295 -1.2981702   0.38957093  0.15942441]
#   [-0.18579537  0.73479071  1.54030352 -0.60773065]]]

# %% [markdown]
# Q2. Using Pandas, filter the rows in the Iris dataset where the petal length is greater than 3.0, and display the filtered data

# %%
from sklearn.datasets import load_iris

iris=load_iris()
irisdf=pd.DataFrame(iris.data, columns=iris.feature_names)
irisdfnew=irisdf[irisdf["petal length (cm)"]>3]
irisdfnew
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [99 rows x 4 columns]

# %% [markdown]
# Q3. Using Matplotlib, plot a line graph showing the trend of a numerical dataset. Customize the plot with title, axis labels, and a legend.

# %%
# We use the load_iris dataset. 
# %matplotlib inline

x=irisdf["sepal length (cm)"]
y=irisdf["sepal width (cm)"]

plt.plot(x,y,label="Trend")

plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.title("Trend of sepal dimensions")

plt.show();

# %% [markdown]
# Q4.Create a Pandas DataFrame with random values with at least 3 columns and perform the following operations: (i) Replace NaN values with the mean of the column. (ii) Sort the DataFrame based on any two columns.

# %%
mat= np.random.randint(0,10,(4,3))
array=pd.Series([2,3])
df4= pd.DataFrame(mat)

df4["10"]=array
df4
# Out:
#    0  1  2   10
# 0  3  3  1  2.0
# 1  7  8  0  3.0
# 2  5  0  5  NaN
# 3  1  5  2  NaN

# %%
df4["10"].fillna(df4["10"].mean(),inplace=True)
# Out:
# C:\Users\dhara\AppData\Local\Temp\ipykernel_32228\2119501418.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4["10"].fillna(df4["10"].mean(),inplace=True)

# %%
df4
# Out:
#    0  1  2   10
# 0  3  3  1  2.0
# 1  7  8  0  3.0
# 2  5  0  5  2.5
# 3  1  5  2  2.5

# %%
sorted=df4.sort_values(by = [0,2],ascending=[True, True])
sorted
# Out:
#    0  1  2   10
# 3  1  5  2  2.5
# 0  3  3  1  2.0
# 2  5  0  5  2.5
# 1  7  8  0  3.0

# %% [markdown]
# Q5. Using NumPy, calculate the dot product of two matrices and find the determinant of the resulting matrix.

# %%
np.random.seed(2)
a=np.random.randint(1,10,(2,2))
b=np.random.randint(1,10,(2,2))
     
print(np.dot(a, b))
# Out:
# [[108  90]
#  [ 72  62]]

# %%
np.linalg.det(np.dot(a, b))
# Out:
# 216.00000000000045

# %% [markdown]
# Q6. With Pandas, group a DataFrame by a categorical column and calculate the sum of another numerical column for each group.

# %%
df = pd.DataFrame({
    'Class': ['B', 'A', 'C', 'C', 'B', 'A', 'C', 'A', 'A', 'B'],
    'Marks': [88, 80, 79, 45, 80, 90, 34, 85, 100, 90]
})
df.groupby("Class").sum("Marks")
# Out:
#        Marks
# Class
# A        355
# B        258
# C        158

# %% [markdown]
# Q7. Using Matplotlib, create a histogram to show the distribution of a numerical dataset. Customize the number of bins and add grid lines for better readability.

# %%
df = pd.DataFrame({
    
    'Student ID': range(1, 21),  # 20 unique students
    'Marks': [45, 78, 88, 56, 90, 67, 78, 85, 93, 74, 60, 65, 79, 84, 92, 70, 88, 64, 95, 72]})
df["Marks"].hist(grid=False)
plt.show();

# %%
df = pd.DataFrame({
    
    'Student ID': range(1, 21),  # 20 unique students
    'Marks': [45, 78, 88, 56, 90, 67, 78, 85, 93, 74, 60, 65, 79, 84, 92, 70, 88, 64, 95, 72]})
df["Marks"].hist(bins=15,grid=True)
plt.show();

# %% [markdown]
# Q8. Using NumPy, create a 2D array and perform a slicing operation to extract a specific sub-array.

# %%
arr=np.random.randint(1,10,(2,3))
print(arr)
arr.ndim
# Out:
# [[8 2 7]
#  [9 6 4]]
# 2

# %%
arr[:1,1:3]
# Out:
# array([[2, 7]])

# %% [markdown]
# Q9. Using Pandas, perform a merge operation between two DataFrames based on a common column for dataset of your choice.

# %%
students_df = pd.DataFrame({
    'Roll Number': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva']
})

scores_df = pd.DataFrame({
    'Roll Number': [1, 2, 4, 7],
    'Marks': [85, 90, 88, 75]
})
merged_df = pd.merge(students_df, scores_df, on='Roll Number')
print("Merged DataFrame:")
print(merged_df)
# Out:
# Merged DataFrame:
#    Roll Number   Name  Marks
# 0            1  Alice     85
# 1            2    Bob     90
# 2            4  David     88

# %% [markdown]
# Q10. Using Matplotlib, create a scatter plot comparing two numerical variables in the dataset of your choice. Customize the plot by changing the color and shape of the data points.

# %%
x = range(0,100,2)
y = np.random.randint(1,100,(50,))

fig, ax = plt.subplots()

ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")
ax.scatter(x,y)

plt.show()

# %%
x = range(0,100,2)
y = np.random.randint(1,100,(50,))

fig, ax = plt.subplots()

ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")
ax.scatter(x,y,c="red",edgecolors="black",marker='^')

plt.show()
